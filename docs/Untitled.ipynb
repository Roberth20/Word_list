# %%
import pandas as pd

# %%
df=pd.read_excel("Word_list.xlsx", index_col="ID")
df
# Out:
#            Word           Traduccion      Translate  Nivel
# ID
# 0          able                capaz            NaN      0
# 1       account               cuenta  dar cuenta de      0
# 2        actual                 real            NaN      0
# 3           add               anadir            NaN      0
# 4       address            direccion            NaN      0
# 5       advance              avanzar            NaN      0
# 6     advantage              ventaja            NaN      0
# 7       affairs              asuntos            NaN      0
# 8           age                 edad            NaN      0
# 9         agree     estar de acuerdo            NaN      0
# 10    agreement              acuerdo            NaN      0
# 11          air                  air            NaN      0
# 12          all                 todo          todos      0
# 13        allow             permitir            NaN      0
# 14        alone                 solo           sola      0
# ...

# %%
df.to_excel("Word_list0.xlsx",index_label="ID")
